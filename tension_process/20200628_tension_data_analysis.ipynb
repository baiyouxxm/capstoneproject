# %%
import pandas as pd
import glob
import numpy as np

path = r'C:\Users\xaa2cng\Documents\tension\Tension_20200628' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
import matplotlib.pyplot as plt

# %%
frame.shape
# Out:
# (11962005, 8)

# %%
frame.head()
# Out:
#    Unnamed: 0  productNo                 readtime  signal  tensionLeft  \
# 0           0    40001.0  2020-06-28 00:00:20:813       1      6.57039
# 1           1    40001.0  2020-06-28 00:00:20:816       1      7.15928
# 2           2    40001.0  2020-06-28 00:00:20:820       1      7.86682
# 3           3    40001.0  2020-06-28 00:00:20:823       1      8.63222
# 4           4    40001.0  2020-06-28 00:00:20:826       1      9.49516
#
#    tensionRight  voltageLeft  voltageRight
# 0       5.92779      0.10547       0.09582
# 1       6.03522      0.10561       0.09571
# 2       6.41939      0.10559       0.09516
# 3       6.98642      0.10552       0.09604
# 4       7.79907      0.10548       0.09565

# %%
my_tab = pd.crosstab(index=frame["productNo"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab
# Out:
# col_0      count
# productNo
# 0.0          148
# 40001.0     6266
# 40002.0     6268
# 40003.0     6263
# 40005.0     6259
# 40006.0     6271
# 40007.0     6269
# 40008.0     6256
# 40009.0     6264
# 40011.0     6270
# 40012.0     6269
# 40013.0     6267
# 40014.0     6262
# 40015.0     6261
# 40016.0     6275
# 40017.0     6262
# 40018.0     6268
# 40019.0     6266
# 40020.0     6271
# 40021.0     6271
# 40022.0     6267
# 40023.0     6261
# 40025.0     6261
# 40026.0     6263
# 40027.0     6257
# 40029.0     6267
# 40030.0     6251
# 40031.0     6277
# 40033.0     6267
# 40035.0     6260
# ...          ...
# 43520.0     6268
# 43521.0     6262
# 43522.0     6253
# 43523.0     6270
# 43524.0     6273
# 43525.0     6264
# 43526.0     6271
# 43527.0     6266
# 43528.0     6265
# 43529.0     6260
# 43531.0     6271
# 43532.0     6269
# 43533.0     6274
# 43534.0     6247
# 43536.0     6250
# 43537.0     6271
# 43539.0     6274
# 43541.0     6268
# 43542.0     6278
# 43544.0     6272
# ...

# %%
my_tab['count'].describe()
# Out:
# count     1853.000000
# mean      6454.498111
# std       2296.008866
# min        148.000000
# 25%       6262.000000
# 50%       6268.000000
# 75%       6273.000000
# max      87561.000000
# Name: count, dtype: float64

# %%
import seaborn as sns
sns.set(style="whitegrid")
ax = sns.boxplot(x=my_tab['count'])

# %%
sorted(my_tab['count'])
# Out:
# [148,
#  529,
#  706,
#  846,
#  923,
#  1041,
#  1408,
#  1516,
#  1924,
#  2189,
#  2637,
#  2861,
#  3050,
#  3160,
#  3218,
#  3393,
#  3625,
#  3682,
#  3711,
#  3813,
#  3880,
#  4032,
#  4068,
#  4102,
#  4149,
#  4253,
#  4340,
#  4745,
#  4783,
#  4854,
#  4909,
#  4984,
#  5131,
#  5154,
#  5171,
#  5242,
#  5306,
#  5336,
#  5349,
#  5418,
#  5450,
#  5454,
#  5568,
#  5571,
#  5594,
#  5622,
#  5635,
#  5732,
#  5882,
#  5979,
#  6030,
#  6032,
#  6065,
#  6080,
#  6083,
#  6104,
#  6124,
#  6128,
#  6135,
#  6136,
#  6147,
#  6177,
#  6181,
#  6182,
#  6190,
#  6206,
#  6208,
#  6215,
#  6218,
#  6225,
#  6225,
#  6226,
#  6230,
#  6235,
#  6239,
#  6240,
#  6244,
#  6245,
#  6246,
#  6246,
#  6247,
#  6247,
#  6247,
#  6248,
#  6248,
#  6249,
#  6249,
#  6249,
#  6249,
#  6249,
#  6249,
#  6249,
#  6250,
#  6250,
#  6250,
#  6250,
#  6250,
#  6251,
#  6251,
#  6251,
#  6251,
#  6251,
#  6251,
#  6251,
#  6251,
#  6251,
#  6251,
#  6252,
#  6252,
#  6252,
#  6252,
# ...

# %%
sorted(my_tab['count'],reverse=True)
# Out:
# [87561,
#  26445,
#  19695,
#  18984,
#  18830,
#  12715,
#  12563,
#  12555,
#  12555,
#  12553,
#  12550,
#  12547,
#  12547,
#  12546,
#  12546,
#  12545,
#  12545,
#  12544,
#  12544,
#  12543,
#  12543,
#  12541,
#  12540,
#  12539,
#  12538,
#  12538,
#  12538,
#  12537,
#  12537,
#  12534,
#  12534,
#  12534,
#  12534,
#  12534,
#  12533,
#  12533,
#  12533,
#  12531,
#  12530,
#  12530,
#  12528,
#  12528,
#  12527,
#  12526,
#  12525,
#  12523,
#  12520,
#  12518,
#  12514,
#  12477,
#  12343,
#  12318,
#  8840,
#  8723,
#  8659,
#  8519,
#  8501,
#  8447,
#  8423,
#  8376,
#  8283,
#  7761,
#  7635,
#  7608,
#  7540,
#  7261,
#  7000,
#  6749,
#  6606,
#  6555,
#  6544,
#  6482,
#  6464,
#  6450,
#  6450,
#  6447,
#  6446,
#  6404,
#  6402,
#  6401,
#  6395,
#  6373,
#  6362,
#  6362,
#  6356,
#  6356,
#  6353,
#  6351,
#  6347,
#  6339,
#  6331,
#  6329,
#  6325,
#  6313,
#  6308,
#  6306,
#  6295,
#  6292,
#  6292,
#  6290,
#  6289,
#  6289,
#  6289,
#  6289,
#  6288,
# ...

# %%
freqtable=my_tab[(my_tab['count']<6300)&(my_tab['count']>6200)]

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=freqtable['count'], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Number of records for each product')
plt.ylabel('Frequency')
plt.title('Histogram of the occurances for each product')
# Out:
# Text(0.5, 1.0, 'Histogram of the occurances for each product')

# %%
normaldata
# Out:
# col_0      count
# productNo
# 40001.0     6266
# 40002.0     6268
# 40003.0     6263
# 40005.0     6259
# 40006.0     6271
# 40007.0     6269
# 40008.0     6256
# 40009.0     6264
# 40011.0     6270
# 40012.0     6269
# 40013.0     6267
# 40014.0     6262
# 40015.0     6261
# 40016.0     6275
# 40017.0     6262
# 40018.0     6268
# 40019.0     6266
# 40020.0     6271
# 40021.0     6271
# 40022.0     6267
# 40023.0     6261
# 40025.0     6261
# 40026.0     6263
# 40027.0     6257
# 40029.0     6267
# 40030.0     6251
# 40031.0     6277
# 40033.0     6267
# 40035.0     6260
# 40036.0     6266
# ...          ...
# 43519.0     6263
# 43520.0     6268
# 43521.0     6262
# 43522.0     6253
# 43523.0     6270
# 43524.0     6273
# 43525.0     6264
# 43526.0     6271
# 43527.0     6266
# 43528.0     6265
# 43529.0     6260
# 43531.0     6271
# 43532.0     6269
# 43533.0     6274
# 43534.0     6247
# 43536.0     6250
# 43537.0     6271
# 43539.0     6274
# 43541.0     6268
# 43542.0     6278
# ...

# %%
freqtable
# Out:
# col_0      count
# productNo
# 40001.0     6266
# 40002.0     6268
# 40003.0     6263
# 40005.0     6259
# 40006.0     6271
# 40007.0     6269
# 40008.0     6256
# 40009.0     6264
# 40011.0     6270
# 40012.0     6269
# 40013.0     6267
# 40014.0     6262
# 40015.0     6261
# 40016.0     6275
# 40017.0     6262
# 40018.0     6268
# 40019.0     6266
# 40020.0     6271
# 40021.0     6271
# 40022.0     6267
# 40023.0     6261
# 40025.0     6261
# 40026.0     6263
# 40027.0     6257
# 40029.0     6267
# 40030.0     6251
# 40031.0     6277
# 40033.0     6267
# 40035.0     6260
# 40036.0     6266
# ...          ...
# 43519.0     6263
# 43520.0     6268
# 43521.0     6262
# 43522.0     6253
# 43523.0     6270
# 43524.0     6273
# 43525.0     6264
# 43526.0     6271
# 43527.0     6266
# 43528.0     6265
# 43529.0     6260
# 43531.0     6271
# 43532.0     6269
# 43533.0     6274
# 43534.0     6247
# 43536.0     6250
# 43537.0     6271
# 43539.0     6274
# 43541.0     6268
# 43542.0     6278
# ...

# %%
normaldata.count()/my_tab['count'].count()
# Out:
# col_0
# count    0.913114
# dtype: float64

# %%
normaldata.count()
# Out:
# col_0
# count    1692
# dtype: int64

# %%
type(frame['readtime'])
# Out:
# pandas.core.series.Series

# %%
frame['readtime'][0]
# Out:
# '2020-06-28 00:00:20:813'

# %%
frame['readtime'][-1:]
# Out:
# 11962004    2020-06-28 17:59:59:999
# Name: readtime, dtype: object

# %%
np.diff(ini_list)

# %%
i=0
product_id=normaldata.index[i]
subframe=frame[frame['productNo']==product_id]

# %%
np.diff(subframe['voltageLeft'])
# Out:
# array([ 1.4e-04, -2.0e-05, -7.0e-05, ...,  7.5e-04, -1.6e-04, -8.0e-04])

# %%
subframe['voltageLeft']
# Out:
# 0       0.10547
# 1       0.10561
# 2       0.10559
# 3       0.10552
# 4       0.10548
# 5       0.10542
# 6       0.10468
# 7       0.10328
# 8       0.10210
# 9       0.10083
# 10      0.09934
# 11      0.09818
# 12      0.09664
# 13      0.09508
# 14      0.09368
# 15      0.09221
# 16      0.09062
# 17      0.08875
# 18      0.08763
# 19      0.08640
# 20      0.08482
# 21      0.08308
# 22      0.08192
# 23      0.08103
# 24      0.07996
# 25      0.07877
# 26      0.07753
# 27      0.07674
# 28      0.07602
# 29      0.07486
#          ...
# 6236    0.07802
# 6237    0.07945
# 6238    0.08127
# 6239    0.08338
# 6240    0.08523
# 6241    0.08740
# 6242    0.08963
# 6243    0.09154
# 6244    0.09426
# 6245    0.09583
# 6246    0.09854
# 6247    0.10041
# 6248    0.10258
# 6249    0.10461
# 6250    0.10664
# 6251    0.10827
# 6252    0.10995
# 6253    0.11152
# 6254    0.11350
# 6255    0.11504
# 6256    0.11669
# 6257    0.11713
# 6258    0.11858
# 6259    0.12024
# ...

# %%
window_size = 50

numbers_series = subframe['tensionLeft']
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
without_nans = moving_averages_list[window_size - 1:]

plt.plot(without_nans)
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('num')
# giving a title to my graph 
plt.title('Moving average of 50 data points for tension Left') 
# function to show the plot 
plt.show()

# %%
window_size = 100

numbers_series = subframe['tensionLeft']
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
without_nans = moving_averages_list[window_size - 1:]
plt.plot(without_nans)
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('num')
# giving a title to my graph 
plt.title('Moving average of 100 data points for tension Left') 
# function to show the plot 
plt.show()

# %%
window_size = 50

numbers_series = subframe['voltageLeft']
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
voltageleft_without_nans_ma = moving_averages_list[window_size - 1:]

# %%
import matplotlib.pyplot as plt 
plt.plot(subframe['tensionLeft'])
#plt.plot(subframe['tensionRight'])
plt.plot(subframe['voltageLeft'])
#plt.plot(subframe['voltageRight'])
plt.legend(['tensionLeft',  'voltageLeft'], loc='upper left')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True)
fig.suptitle('One product cycle original data')
ax1.plot(subframe['tensionLeft'])
ax1.set_title('tensionLeft')
ax2.plot(subframe['voltageLeft'])
ax2.set_title('voltageLeft')
#ax3.plot(subframe['voltageLeft'])
#ax4.plot(subframe['voltageRight'])
# Out:
# Text(0.5, 1.0, 'voltageLeft')

# %%
window_size = 50

numbers_series = subframe['tensionLeft']
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
tensionleft_ma = moving_averages_list[window_size - 1:]

numbers_series = subframe['voltageLeft']
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
voltageleft_ma= moving_averages_list[window_size - 1:]

fig, (ax1, ax2) = plt.subplots(2, sharex=True)
fig.suptitle('One product cycle moving average of windown size 50')
ax1.plot(tensionleft_ma)
ax1.set_title('tensionLeft_MA')
ax2.plot(voltageleft_ma)
ax2.set_title('voltageLeft_MA')
# Out:
# Text(0.5, 1.0, 'voltageLeft_MA')

# %%
np.std(tensionleft_ma[1600:1800])
# Out:
# 0.02228216775998351

# %%
np.std(tensionleft_ma[2000:2200])
# Out:
# 0.1048696228925821

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
x = np.array(voltageleft_ma).reshape((-1, 1))
y = tensionleft_ma
model = LinearRegression()
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.6769333876050965
# intercept: 1.335632790039531
# slope: [72.28482768]

# %%
import statsmodels.api as sm
X = voltageleft_ma
y = tensionleft_ma
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                 1.302e+04
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):               0.00
# Time:                        13:34:32   Log-Likelihood:                -8479.2
# No. Observations:                6217   AIC:                         1.696e+04
# Df Residuals:                    6215   BIC:                         1.698e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3356      0.063     21.206      0.000       1.212       1.459
# ...

# %%
import statsmodels.api as sm
from itertools import chain
X = list(chain(voltage[0:2], [a[4]], a[6:]))
y = tensionleft_ma[[600:800]&[1600:1800]]
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#   File "<ipython-input-79-75c004031f98>", line 2
#     X = voltageleft_ma[[600:800]&[1600:1800]]
#                            ^
# SyntaxError: invalid syntax

# %%
type(tensionleft_ma)
# Out:
# list

# %%
import statsmodels.api as sm
X = voltageleft_ma[1600:1800]
y = tensionleft_ma[1600:1800]
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())

# %%
type(est2.summary())
# Out:
# statsmodels.iolib.summary.Summary

# %%
import numpy as np
np.sqrt(0.40612)
# Out:
# 0.6372754506490894

# %%
np.sqrt(0.6769333876050965)
# Out:
# 0.8227596171453097

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
x = np.array(subframe['voltageLeft']).reshape((-1, 1))
y = np.array(subframe['tensionLeft']).reshape((-1, 1))
model = LinearRegression()
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.4061257575058653
# intercept: [1.56741393]
# slope: [[69.86237283]]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
x = np.array(subframe['voltageLeft']).reshape((-1, 1))
y = np.array(subframe['tensionLeft'])
model = LinearRegression()
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.4061257575058653
# intercept: 1.567413932828182
# slope: [69.86237283]

# %%
dfreg =  pd.DataFrame(columns=['Intercept', 'Slope'])
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
for i in range(18):    
    productid=freqtable.index[i+1]
    subframe=frame[frame['productNo']==productid]
    subframe.drop(['Unnamed: 0','signal','productNo'],axis=1,inplace=True)
    X = subframe['voltageRight'].values.reshape((-1, 1))
    y = subframe['voltageLeft'].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    regressor = LinearRegression()  
    regressor.fit(X_train, y_train)
    #coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
    #coeff_df
    #print('intercept:', regressor.intercept_)
    #print('slope:', regressor.coef_)
    
    # Convert the dictionary into DataFrame 
    #df = pd.DataFrame(data)
   # li.append(df)
    #regtotal = pd.concat(df, axis=0, ignore_index=False)
    dfreg.loc[i]=[regressor.intercept_,regressor.coef_[0]]
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# ...

# %%
dfreg
# Out:
#     Intercept     Slope
# 0   -0.003835  1.134615
# 1   -0.003714  1.133215
# 2   -0.003692  1.133014
# 3   -0.003970  1.135895
# 4   -0.003863  1.134933
# 5   -0.003775  1.133714
# 6   -0.003806  1.134602
# 7   -0.003719  1.133592
# 8   -0.003718  1.133236
# 9   -0.003738  1.133966
# 10  -0.003688  1.133197
# 11  -0.003741  1.133660
# 12  -0.003721  1.133343
# 13  -0.003655  1.133272
# 14  -0.003528  1.131532
# 15  -0.003745  1.133729
# 16  -0.003741  1.133732
# 17  -0.003840  1.134533

# %%
dfreg
# Out:
#     Intercept     Slope
# 0    0.000000  0.000000
# 1    0.003446  0.880738
# 2    0.003578  0.879326
# 3    0.003487  0.880300
# 4    0.003462  0.880518
# 5    0.003671  0.878554
# 6    0.003601  0.879091
# 7    0.003545  0.879848
# 8    0.003593  0.878923
# 9    0.003506  0.879845
# 10   0.003521  0.879965
# 11   0.003505  0.879724
# 12   0.003441  0.880547
# 13   0.003517  0.879870
# 14   0.003490  0.880222
# 15   0.003460  0.879999
# 16   0.003382  0.881057
# 17   0.003517  0.879860

# %%
1/0.879860
# Out:
# 1.1365444502534494

# %%
for i in range(18):
    productid=freqtable.index[i]
    subframe=frame[frame['productNo']==productid]
    plt.figure()
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True)
    fig.suptitle('Variables change through product ID '+str(productid))
    ax1.plot(np.arange(subframe.shape[0])+1,subframe['tensionLeft'])
    ax1.set_title('tensionLeft')
    ax2.plot(np.arange(subframe.shape[0])+1,subframe['tensionRight'])
    ax2.set_title('tensionRight')
    ax3.plot(np.arange(subframe.shape[0])+1,subframe['voltageLeft'])
    ax3.set_title('voltageLeft')
    ax4.plot(np.arange(subframe.shape[0])+1,subframe['voltageRight'])
    ax4.set_title('voltageRight')
    #plt.xlabel('Time(ms)')
    #plt.ylabel('EMG voltage(microV)')
    plt.savefig('Tension {0}.jpg'.format(productid))
    plt.close()

# %%
for i in range(18):
    productid=freqtable.index[i]
    subframe=frame[frame['productNo']==productid]
    subframe.drop(['Unnamed: 0','signal','productNo'],axis=1,inplace=True)
    corr=subframe.corr()
    sns.set(style="white")
    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(corr, dtype=np.bool))
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))
    f.suptitle('Correlation coefficient of product ID '+str(productid))
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0.85,
                square=True, linewidths=.5, cbar_kws={"shrink": .5},annot= True)
    #plt.xlabel('Time(ms)')
    #plt.ylabel('EMG voltage(microV)')
    plt.savefig('Correlation {0}.jpg'.format(productid))
    plt.close()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
for i in range(18):
    productid=int(freqtable.index[i])
    subframe=frame[frame['productNo']==productid]
    subframe.drop(['Unnamed: 0','signal','productNo'],axis=1,inplace=True)
    #f, ax = plt.subplots(figsize=(11, 9))
    #f.suptitle('Scatterplot of product ID '+str(productid))
    g = sns.PairGrid(subframe)
    g.map_diag(plt.hist, edgecolor="w")
    g.map_upper(plt.scatter)
    g.map_lower(sns.kdeplot)
    #g.title('Scatterplot of product ID '+str(productid))
    #plt.xlabel('Time(ms)')
    #plt.ylabel('EMG voltage(microV)')
    g.fig.suptitle('Scatterplot of product ID '+str(productid))
    plt.savefig('Scatterplot {0}.jpg'.format(productid))
    plt.close()

# %%
dfreg =  pd.DataFrame(columns=['Intercept', 'Slope'])
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
for i in range(18):    
    productid=freqtable.index[i+1]
    subframe=frame[frame['productNo']==productid]
    subframe.drop(['Unnamed: 0','signal','productNo'],axis=1,inplace=True)
    X = subframe['tensionRight'].values.reshape((-1, 1))
    y = subframe['tensionLeft'].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    regressor = LinearRegression()  
    regressor.fit(X_train, y_train)
    #coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
    #coeff_df
    #print('intercept:', regressor.intercept_)
    #print('slope:', regressor.coef_)
    
    # Convert the dictionary into DataFrame 
    #df = pd.DataFrame(data)
   # li.append(df)
    #regtotal = pd.concat(df, axis=0, ignore_index=False)
    dfreg.loc[i]=[regressor.intercept_,regressor.coef_[0]]
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# ...

# %%
dfreg
# Out:
#     Intercept     Slope
# 0   -0.611508  1.222064
# 1   -0.751957  1.237855
# 2   -0.809769  1.250924
# 3   -0.643261  1.233086
# 4   -0.222706  1.198955
# 5   -0.106925  1.178496
# 6   -0.227982  1.184789
# 7   -0.868658  1.257046
# 8   -0.937195  1.268344
# 9   -0.709842  1.238659
# 10  -0.888786  1.256545
# 11  -1.060797  1.276981
# 12  -0.976359  1.261952
# 13  -0.793277  1.244292
# 14  -0.494802  1.209115
# 15   0.003161  1.151461
# 16  -0.763518  1.228728
# 17  -0.759761  1.240029
