# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
tension1 =r'C:\Users\xaa2cng\Documents\tension\0530\tension_2020_05_30_2020-05-30_00_00_00.csv'
df1 = pd.read_csv(tension1, sep=',')
df1.head()
# Out:
#    Unnamed: 0  productNo                 readtime  signal  tensionLeft  \
# 0           0        0.0  2020-05-30 00:00:00:003       1      7.56908
# 1           1        0.0  2020-05-30 00:00:00:003       1      7.58959
# 2           2        0.0  2020-05-30 00:00:00:003       1      7.58910
# 3           3        0.0  2020-05-30 00:00:00:003       1      7.60949
# 4           4        0.0  2020-05-30 00:00:00:003       1      7.59789
#
#    tensionRight  voltageLeft  voltageRight
# 0       6.27522      0.07956       0.08061
# 1       6.25239      0.07920       0.08086
# 2       6.25690      0.07947       0.08057
# 3       6.35090      0.07945       0.08068
# 4       6.45222      0.07998       0.08057

# %%
plt.plot(df1['tensionLeft'])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Left tension')
# giving a title to my graph 
plt.title('Dynamic change') 
# function to show the plot 
plt.show()

# %%
df1.shape
# Out:
# (375903, 8)

# %%
plt.plot(df1['tensionLeft'][1:6100])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Left tension')
# giving a title to my graph 
plt.title('Dynamic change') 
# function to show the plot 
plt.show()

# %%
plt.plot(df1['tensionLeft'][6101:12200])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Left tension')
# giving a title to my graph 
plt.title('Dynamic change') 
# function to show the plot 
plt.show()

# %%
plt.plot(df1['tensionLeft'][12201:18300])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Left tension')
# giving a title to my graph 
plt.title('Dynamic change') 
# function to show the plot 
plt.show()

# %%
plt.plot(df1['tensionLeft'][18301:24400])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Left tension')
# giving a title to my graph 
plt.title('Dynamic change') 
# function to show the plot 
plt.show()

# %%
plt.plot((df1['tensionLeft'][18301:24400]).to_numpy()-(df1['tensionLeft'][12201:18300]).to_numpy())
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Left tension')
# giving a title to my graph 
plt.title('Dynamic change') 
# function to show the plot 
plt.show()

# %%
type(df1['tensionLeft'][18301:24400])
# Out:
# pandas.core.series.Series

# %%
(df1['tensionLeft'][18301:24400]).to_numpy()-(df1['tensionLeft'][12201:18300]).to_numpy()
# Out:
# array([ 0.40992,  0.40187,  0.37086, ..., -0.54994, -0.53944, -0.58095])

# %%
plt.plot(df1['tensionLeft'][24401:30500])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Left tension')
# giving a title to my graph 
plt.title('Dynamic change') 
# function to show the plot 
plt.show()

# %%
Zeroseries=df1['tensionLeft'][df1['tensionLeft']==min(df1['tensionLeft'][24401:30500])]

# %%
Diffbtzero_original=np.diff(Zeroseries.index.to_numpy())

# %%
type(Diffbtzero)
# Out:
# numpy.ndarray

# %%
Diffbtzero_original
# Out:
# array([6049, 6041, 5997, 6229, 6161, 6129, 6145, 6118,    1, 5931, 6318,
#        6183, 6073, 6141,    1, 6024, 6146, 6056, 6178, 5948, 6257, 6111,
#        6217, 6097, 6041, 5944, 6358, 6015, 6060, 5947, 6346, 6080, 6085,
#        6101, 6083, 6085, 6011, 5929, 6095, 6076, 6103, 6088, 6085, 6069,
#        6103, 6044, 5988, 6179, 5929, 6120, 6390, 6123, 6013, 5920, 5957,
#        6606, 5940, 6314, 6033, 6234, 6072, 6014], dtype=int64)

# %%
Diffbtzero_removed=Diffbtzero_original[Diffbtzero_original!=1]

# %%
Diffbtzero_removed
# Out:
# array([6049, 6041, 5997, 6229, 6161, 6129, 6145, 6118, 5931, 6318, 6183,
#        6073, 6141, 6024, 6146, 6056, 6178, 5948, 6257, 6111, 6217, 6097,
#        6041, 5944, 6358, 6015, 6060, 5947, 6346, 6080, 6085, 6101, 6083,
#        6085, 6011, 5929, 6095, 6076, 6103, 6088, 6085, 6069, 6103, 6044,
#        5988, 6179, 5929, 6120, 6390, 6123, 6013, 5920, 5957, 6606, 5940,
#        6314, 6033, 6234, 6072, 6014], dtype=int64)

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=Diffbtzero_removed, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.distplot(Diffbtzero_removed)
