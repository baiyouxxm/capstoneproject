# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#the CISS and time information
maylink = r"C:\Users\xaa2cng\Documents\turning\original_data_may\2020_05_06T08_set.csv"
maydf = pd.read_csv(maylink, sep=',')

# %%
maydf.head()
# Out:
#      num                 time        x      y      z
# 0  72298  2020-05-06 17:19:48   -279.0  554.0  480.0
# 1  72298  2020-05-06 17:19:48   -363.0  462.0  314.0
# 2  72298  2020-05-06 17:19:48  -1626.0  390.0   56.0
# 3  72298  2020-05-06 17:19:48  -1528.0  640.0  107.0
# 4  72298  2020-05-06 17:19:48  -2158.0  755.0  -35.0

# %%
maydf.convert_objects(convert_numeric=True)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#                num                 time       x      y      z
# 0          72298.0  2020-05-06 17:19:48  -279.0  554.0  480.0
# 1          72298.0  2020-05-06 17:19:48  -363.0  462.0  314.0
# 2          72298.0  2020-05-06 17:19:48 -1626.0  390.0   56.0
# 3          72298.0  2020-05-06 17:19:48 -1528.0  640.0  107.0
# 4          72298.0  2020-05-06 17:19:48 -2158.0  755.0  -35.0
# 5          72298.0  2020-05-06 17:19:48 -1563.0  152.0 -148.0
# 6          72298.0  2020-05-06 17:19:48  -259.0  -44.0   37.0
# 7          72298.0  2020-05-06 17:19:48  -421.0   62.0  163.0
# ...

# %%
maydf.head()
# Out:
#      num                 time        x      y      z
# 0  72298  2020-05-06 17:19:48   -279.0  554.0  480.0
# 1  72298  2020-05-06 17:19:48   -363.0  462.0  314.0
# 2  72298  2020-05-06 17:19:48  -1626.0  390.0   56.0
# 3  72298  2020-05-06 17:19:48  -1528.0  640.0  107.0
# 4  72298  2020-05-06 17:19:48  -2158.0  755.0  -35.0

# %%
maydf.convert_objects(convert_numeric=True).dropna()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#                num                 time       x      y      z
# 0          72298.0  2020-05-06 17:19:48  -279.0  554.0  480.0
# 1          72298.0  2020-05-06 17:19:48  -363.0  462.0  314.0
# 2          72298.0  2020-05-06 17:19:48 -1626.0  390.0   56.0
# 3          72298.0  2020-05-06 17:19:48 -1528.0  640.0  107.0
# 4          72298.0  2020-05-06 17:19:48 -2158.0  755.0  -35.0
# 5          72298.0  2020-05-06 17:19:48 -1563.0  152.0 -148.0
# 6          72298.0  2020-05-06 17:19:48  -259.0  -44.0   37.0
# 7          72298.0  2020-05-06 17:19:48  -421.0   62.0  163.0
# ...

# %%
maydf2 = maydf['x'.apply(lambda x: pd.to_numeric(x, errors='coerce')).dropna()

# %%
maydf2 = maydf[['num','x','y','z']]

# %%
maydf3 = maydf2.apply(lambda x: pd.to_numeric(x, errors='coerce')).dropna()

# %%
#res = maydf[pd.to_numeric(maydf['x','y',], errors='coerce').notnull()]
#res['x'] = res['x'].astype(float)

# %%
maydf3.shape
# Out:
# (128365813, 4)

# %%
maydf3.head()
# Out:
#        num       x      y      z
# 0  72298.0  -279.0  554.0  480.0
# 1  72298.0  -363.0  462.0  314.0
# 2  72298.0 -1626.0  390.0   56.0
# 3  72298.0 -1528.0  640.0  107.0
# 4  72298.0 -2158.0  755.0  -35.0

# %%
maydf.shape
# Out:
# (128408695, 5)

# %%
maydf3.shape
# Out:
# (128365813, 4)

# %%
type(maydf3['x'])
# Out:
# pandas.core.series.Series

# %%
type(maydf['time'])
# Out:
# pandas.core.series.Series

# %%
type(maydf['time'][0])
# Out:
# str

# %%
np.unique(maydf3['num'])
# Out:
# array([0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 8.9997e+04, 8.9998e+04,
#        8.9999e+04])

# %%
def f7(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]

# %%
f7(maydf3['num'])
# Out:
# [72298.0,
#  72299.0,
#  72300.0,
#  72301.0,
#  72302.0,
#  72303.0,
#  72304.0,
#  72305.0,
#  72306.0,
#  72307.0,
#  72308.0,
#  72309.0,
#  72310.0,
#  72311.0,
#  72312.0,
#  72313.0,
#  72314.0,
#  72315.0,
#  72316.0,
#  72317.0,
#  72318.0,
#  72319.0,
#  72320.0,
#  72321.0,
#  72322.0,
#  72323.0,
#  72324.0,
#  72325.0,
#  72326.0,
#  72327.0,
#  72328.0,
#  72329.0,
#  72330.0,
#  72331.0,
#  72332.0,
#  72333.0,
#  72334.0,
#  72335.0,
#  72336.0,
#  72337.0,
#  72338.0,
#  72339.0,
#  72340.0,
#  72341.0,
#  72342.0,
#  72343.0,
#  72344.0,
#  72345.0,
#  72346.0,
#  72347.0,
#  72348.0,
#  72349.0,
#  72350.0,
#  72351.0,
#  72352.0,
#  72353.0,
#  72354.0,
#  72355.0,
#  72356.0,
#  72357.0,
#  72358.0,
#  72359.0,
#  72360.0,
#  72361.0,
#  72362.0,
#  72363.0,
#  72364.0,
#  72365.0,
#  72366.0,
#  72367.0,
#  72368.0,
#  72369.0,
#  72370.0,
#  72371.0,
#  72372.0,
#  72373.0,
#  72374.0,
#  72375.0,
#  72376.0,
#  72377.0,
#  72378.0,
#  72379.0,
#  72380.0,
# ...

# %%
type(maydf3['x'][0])
# Out:
# numpy.float64

# %%
maydf['time'][-5:]
# Out:
# 128408690    2020-05-08 17:03:17
# 128408691    2020-05-08 17:03:17
# 128408692    2020-05-08 17:03:17
# 128408693    2020-05-08 17:03:17
# 128408694    2020-05-08 17:03:17
# Name: time, dtype: object

# %%
my_tab = pd.crosstab(index=maydf["num"],  # Make a crosstab
                              columns="count")      # Name the count column

my_tab
# Out:
# col_0  count
# num
# 0       6754
# 1       6804
# 10      6802
# 100     6800
# 1000    6802
# 1001    6802
# 1002    6803
# 1003    6802
# 1004    6802
# 1005    6785
# 1006    6802
# 1007    6800
# 1008    6788
# 1009    6788
# 101     6802
# 1010    6800
# 1011    6788
# 1012    6787
# 1013    6803
# 1014    6800
# 1015    6787
# 1016    6803
# 1017    6802
# 1018    6801
# 1019    6802
# 102     6802
# 1020    6802
# 1021    6772
# 1022    6786
# 1023    6802
# ...      ...
# 973     6807
# 974     6785
# 975     6785
# 976     6803
# 977     6785
# 978     6784
# 979     6802
# 98      6798
# 980     6754
# 981     6802
# 982     6786
# 983     6786
# 984     6801
# 985     6803
# 986     6802
# 987     6802
# 988     6802
# 989     6784
# 99      6802
# 990     6804
# 991     6802
# 992     6802
# 993     6802
# 994     6802
# 995     6786
# 996     6802
# 997     6786
# 998     6801
# 999     6803
# num    42882
#
# [18889 rows x 1 columns]

# %%
my_tab['count'].describe()
# Out:
# count    18889.000000
# mean      6798.067394
# std        263.895864
# min       4168.000000
# 25%       6789.000000
# 50%       6802.000000
# 75%       6802.000000
# max      42882.000000
# Name: count, dtype: float64

# %%
my_tab[my_tab['count']==4168]
# Out:
# col_0  count
# num
# 84915   4168

# %%
my_tab[my_tab['count']==5206]
# Out:
# col_0  count
# num
# 86654   5206

# %%
my_tab[my_tab['count']==]

# %%
sorted(my_tab['count'])
# Out:
# [4168,
#  5206,
#  5516,
#  6492,
#  6647,
#  6688,
#  6688,
#  6706,
#  6707,
#  6707,
#  6716,
#  6735,
#  6736,
#  6737,
#  6737,
#  6737,
#  6737,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6738,
#  6739,
#  6739,
#  6739,
#  6740,
#  6740,
#  6740,
#  6743,
#  6745,
#  6749,
#  6749,
#  6750,
#  6750,
#  6750,
#  6750,
#  6750,
#  6750,
#  6750,
#  6750,
#  6750,
#  6751,
#  6751,
#  6751,
#  6751,
#  6751,
#  6751,
#  6751,
#  6751,
#  6751,
#  6751,
#  6751,
#  6752,
#  6752,
#  6752,
#  6752,
#  6752,
#  6752,
#  6752,
#  6752,
#  6752,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6753,
#  6754,
#  6754,
#  6754,
#  6754,
#  6754,
#  6754,
#  6754,
#  6754,
#  6754,
#  6754,
# ...

# %%
sorted(my_tab['count'],reverse=True)
# Out:
# [42882,
#  6820,
#  6818,
#  6817,
#  6816,
#  6814,
#  6814,
#  6814,
#  6813,
#  6812,
#  6812,
#  6812,
#  6811,
#  6811,
#  6811,
#  6811,
#  6810,
#  6810,
#  6810,
#  6810,
#  6810,
#  6810,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6809,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6808,
#  6807,
#  6807,
#  6807,
#  6807,
#  6807,
#  6807,
#  6807,
#  6807,
#  6807,
#  6807,
# ...

# %%
freqtable=my_tab[(my_tab['count']<6821)&(my_tab['count']>6492)]

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=freqtable['count'], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Number of records for each product')
plt.ylabel('Frequency')
plt.title('Histogram of the occurances for each product')
# Out:
# Text(0.5, 1.0, 'Histogram of the occurances for each product')

# %%
freqtable=my_tab[(my_tab['count']<6821)&(my_tab['count']>6775)]
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=freqtable['count'], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Number of records for each product')
plt.ylabel('Frequency')
plt.title('Histogram of the occurances for each product')
# Out:
# Text(0.5, 1.0, 'Histogram of the occurances for each product')

# %%
i=0
productid=freqtable.index[i+1]

# %%
productid
# Out:
# '10'

# %%
meanfeaturex=maydf3.groupby('num', as_index=True)['x'].mean()
meanfeaturex.head()
# Out:
# num
# 0.0   -996.270358
# 1.0   -996.704439
# 2.0   -996.422022
# 3.0   -997.730508
# 4.0   -995.616927
# Name: x, dtype: float64

# %%
meanfeaturex
# Out:
#            num           x
# 0          0.0 -996.270358
# 1          1.0 -996.704439
# 2          2.0 -996.422022
# 3          3.0 -997.730508
# 4          4.0 -995.616927
# 5          5.0 -996.724802
# 6          6.0 -997.314760
# 7          7.0 -995.281810
# 8          8.0 -996.423953
# 9          9.0 -996.990150
# 10        10.0 -996.050573
# 11        11.0 -996.277778
# 12        12.0 -996.918055
# 13        13.0 -997.367669
# 14        14.0 -995.588062
# 15        15.0 -997.843626
# 16        16.0 -996.101426
# 17        17.0 -996.608613
# 18        18.0 -996.787121
# 19        19.0 -996.406218
# 20        20.0 -995.919424
# 21        21.0 -997.581594
# 22        22.0 -996.909879
# 23        23.0 -996.572651
# 24        24.0 -995.638195
# 25        25.0 -996.730775
# 26        26.0 -995.955154
# 27        27.0 -995.842987
# 28        28.0 -997.737245
# 29        29.0 -996.053166
# ...        ...         ...
# 18858  89970.0 -995.721994
# 18859  89971.0 -996.820588
# ...

# %%
meanfeature= maydf3.groupby('num').agg([np.mean, lambda x: x.iloc[1] ])

# %%
maydf3.sort_index(ascending=False).groupby('num').agg([np.mean])
# Out:
#                   x          y           z
#                mean       mean        mean
# num
# 0.0     -996.270358  53.598460 -148.914125
# 1.0     -996.704439  52.624339 -150.172546
# 2.0     -996.422022  51.684552 -150.139151
# 3.0     -997.730508  52.059657 -151.049616
# 4.0     -995.616927  51.605426 -149.771454
# 5.0     -996.724802  52.616074 -149.480018
# 6.0     -997.314760  52.652161 -151.385916
# 7.0     -995.281810  53.125771 -148.527476
# 8.0     -996.423953  52.947098 -150.585452
# 9.0     -996.990150  50.992943 -149.021611
# 10.0    -996.050573  52.615848 -150.076742
# 11.0    -996.277778  52.589596 -149.591217
# 12.0    -996.918055  52.056595 -149.802948
# 13.0    -997.367669  52.603154 -150.691129
# 14.0    -995.588062  52.409438 -150.211261
# 15.0    -997.843626  52.291083 -149.412233
# 16.0    -996.101426  52.603410 -149.108482
# 17.0    -996.608613  52.020870 -149.455173
# 18.0    -996.787121  52.661717 -149.397677
# 19.0    -996.406218  53.029321 -150.767939
# ...

# %%
meanfeaturex=maydf3.groupby('num', as_index=True,sort=False)['x'].mean()
meanfeaturex.head()
# Out:
# num
# 72298.0   -994.794325
# 72299.0   -994.534696
# 72300.0   -993.579388
# 72301.0   -994.539253
# 72302.0   -991.606292
# Name: x, dtype: float64

# %%
meanfeaturex=maydf3.groupby('num', as_index=False,sort=False)['x'].mean()
meanfeaturex.head()
# Out:
#        num           x
# 0  72298.0 -994.794325
# 1  72299.0 -994.534696
# 2  72300.0 -993.579388
# 3  72301.0 -994.539253
# 4  72302.0 -991.606292

# %%
plt.plot(meanfeaturex['x'])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('X_mean')
# giving a title to my graph 
plt.title('Variable: X mean change across different products') 
# function to show the plot 
plt.show()

# %%
meanfeaturex['x'][12550:12500]
# Out:
# 12550    -991.409144
# 12551    -992.162358
# 12552    -989.934725
# 12553    -990.981476
# 12554    -993.047675
# 12555    -992.662305
# 12556    -992.273155
# 12557    -991.654578
# 12558    -992.411350
# 12559   -1004.105922
# 12560   -1004.468755
# 12561   -1004.271214
# 12562   -1003.531020
# 12563   -1004.303213
# 12564   -1004.704499
# 12565   -1003.775192
# 12566   -1003.315054
# 12567   -1002.639004
# 12568   -1003.514113
# 12569   -1005.007368
# 12570   -1003.784034
# 12571   -1004.820570
# 12572   -1003.964496
# 12573   -1004.682977
# 12574   -1004.735519
# 12575   -1004.089878
# 12576   -1004.669362
# 12577   -1003.315402
# 12578   -1004.325246
# 12579   -1003.254025
#             ...
# 18858    -996.433466
# 18859    -997.752132
# 18860    -996.921053
# 18861    -996.874302
# 18862    -996.047339
# 18863    -996.037636
# 18864    -996.750331
# 18865    -996.047780
# 18866    -996.265655
# 18867    -995.975063
# 18868    -996.873287
# 18869    -996.273489
# ...

# %%
meanfeaturex[12557:12560]
# Out:
#            num            x
# 12557  84855.0  -991.654578
# 12558  84856.0  -992.411350
# 12559  84857.0 -1004.105922

# %%
maydf[maydf['num']=='84857']
# Out:
#             num                 time        x       y       z
# 85391836  84857  2020-05-08 00:03:51   -290.0  -195.0    21.0
# 85391837  84857  2020-05-08 00:03:51    -21.0  -456.0  -232.0
# 85391838  84857  2020-05-08 00:03:51   -435.0    74.0  -179.0
# 85391839  84857  2020-05-08 00:03:51  -1130.0  -327.0  -335.0
# 85391840  84857  2020-05-08 00:03:51  -1647.0   142.0  -341.0
# 85391841  84857  2020-05-08 00:03:51  -1452.0   204.0  -368.0
# 85391842  84857  2020-05-08 00:03:51  -1163.0   277.0   -39.0
# 85391843  84857  2020-05-08 00:03:51   -454.0  -152.0    70.0
# 85391844  84857  2020-05-08 00:03:51    -25.0   308.0   335.0
# 85391845  84857  2020-05-08 00:03:51   -895.0   126.0    19.0
# 85391846  84857  2020-05-08 00:03:51    -15.0   113.0    68.0
# 85391847  84857  2020-05-08 00:03:51   -841.0   437.0   107.0
# 85391848  84857  2020-05-08 00:03:51   -960.0   -13.0  -142.0
# 85391849  84857  2020-05-08 00:03:51  -1563.0  -187.0  -222.0
# ...

# %%
meanfeaturey=maydf3.groupby('num', as_index=False,sort=False)['y'].mean()
meanfeaturey.head()
# Out:
#        num           y
# 0  72298.0  137.591150
# 1  72299.0  138.463981
# 2  72300.0  139.277418
# 3  72301.0  137.629080
# 4  72302.0  139.456042

# %%
plt.plot(meanfeaturey['y'])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Y_mean')
# giving a title to my graph 
plt.title('Variable: Y mean change across different products') 
# function to show the plot 
plt.show()

# %%
meanfeaturez=maydf3.groupby('num', as_index=False,sort=False)['z'].mean()
meanfeaturez.head()
# Out:
#        num           z
# 0  72298.0 -131.419288
# 1  72299.0 -130.153778
# 2  72300.0 -132.866951
# 3  72301.0 -130.279918
# 4  72302.0 -128.456777

# %%
plt.plot(meanfeaturez['z'])
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('Z_mean')
# giving a title to my graph 
plt.title('Variable: Z mean change across different products') 
# function to show the plot 
plt.show()

# %%
window_size = 100

numbers_series = meanfeaturex['x']
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
without_nans = moving_averages_list[window_size - 1:]
plt.plot(without_nans)
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('num')
# giving a title to my graph 
plt.title('Moving average of 100 data points for X mean') 
# function to show the plot 
plt.show()

# %%
window_size = 100

numbers_series = meanfeaturey['y']
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
without_nans = moving_averages_list[window_size - 1:]
plt.plot(without_nans)
# naming the x axis 
plt.xlabel('Row Index') 
# naming the y axis 
plt.ylabel('num')
# giving a title to my graph 
plt.title('Moving average of 100 data points for Y mean') 
# function to show the plot 
plt.show()
